# %%
import random
import os
import numpy as np
import torch

def seed_everything(seed=42):
    # 1. Base Python & OS environment
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

    # 2. PyTorch (CPU and GPU)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For multi-GPU setups

    # 3. Force CUDA deterministic algorithms
    # Note: This ensures identical results but can slightly reduce execution speed
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Call it before loading any models or data
seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/sarulab-speech/UTMOSv2.git
# Out:
# ...
#   Cloning https://github.com/sarulab-speech/UTMOSv2.git to /tmp/pip-req-build-rkp0fm6y
#   Running command git clone --filter=blob:none --quiet https://github.com/sarulab-speech/UTMOSv2.git /tmp/pip-req-build-rkp0fm6y
#   Resolved https://github.com/sarulab-speech/UTMOSv2.git to commit cc2700db57bb83ee13dc31ebe1b868c254e15d09
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for utmosv2: filename=utmosv2-1.3.1.dev0-py3-none-any.whl size=79520 sha256=673759d898607c20c6eef87ed817834b36640a1414ade07f0f2cc04f476b2b7e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f5wdpmb5/wheels/59/c9/43/348b910ebc4fc7b58e891b26128a034f4dfd40df8bf938faa0
# Successfully built utmosv2
# ...

# %%
import utmosv2
model = utmosv2.create_model(pretrained=True)
# data: torch.Tensor or np.ndarray with shape (batch_size, sequence_length) or (sequence_length,)
# sr: Sampling rate of the input audio data. If not provided, it defaults to 16000 Hz.
# mos = model.predict(data=data, sr=16000) # Returns a torch.Tensor or np.ndarray with shape (batch_size,) or (1,)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/380M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/211 [00:00<?, ?it/s]
# ...

# %%
model_device = next(model.parameters()).device
print(f"UTMOSv2 is currently running on: {model_device}")
# Out:
# UTMOSv2 is currently running on: cpu

# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# 2.11.0+cu128
# True
# 12.8

# %%
import numpy as np
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/test_16k/default")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting:   0%|          | 0/25 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/utmosv2/_core/model/_common.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Predicting: 100%|██████████| 25/25 [10:12<00:00, 24.49s/it]
# MOS = 3.585 ± 0.239

# %%
import numpy as np
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/test_16k/default")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting:   0%|          | 0/25 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/utmosv2/_core/model/_common.py:290: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Predicting: 100%|██████████| 25/25 [11:03<00:00, 26.53s/it]
# MOS = 3.585 ± 0.239

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/test_16k/vc_david")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:36<00:00, 23.05s/it]
# MOS = 3.051 ± 0.259

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/test_16k/vc_jennifer")
scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:24<00:00, 22.57s/it]
# MOS = 3.664 ± 0.263

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/test_16k/vc_morgan")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:29<00:00, 22.79s/it]
# MOS = 3.165 ± 0.245

# %%
import numpy as np
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/evc_test_16k/david/david_evc_sad")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:25<00:00, 22.60s/it]
# MOS = 3.014 ± 0.266

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/evc_test_16k/david/david_evc_angry")

import numpy as np

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:39<00:00, 23.17s/it]
# MOS = 2.740 ± 0.305

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/evc_test_16k/jennifer/jennifer_evc_angry")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:26<00:00, 22.65s/it]
# MOS = 3.257 ± 0.347

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/evc_test_16k/jennifer/jennifer_evc_sad")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:18<00:00, 22.36s/it]
# MOS = 3.570 ± 0.293

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/evc_test_16k/morgan/morgan_evc_angry")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:28<00:00, 22.72s/it]
# MOS = 3.042 ± 0.290

# %%
mos = model.predict(input_dir="/content/drive/MyDrive/AudioDeepfakesCodes/Data/evc_test_16k/morgan/morgan_evc_sad")

scores = [
    x["predicted_mos"]
    for x in mos
]

mean_mos = np.mean(scores)
std_mos = np.std(scores)

print(f"\nMOS = {mean_mos:.3f} ± {std_mos:.3f}")
# Out:
# Predicting: 100%|██████████| 25/25 [09:18<00:00, 22.36s/it]
# MOS = 3.333 ± 0.605
